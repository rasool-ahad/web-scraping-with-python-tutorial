# %% [markdown]
# # beatiful soup

# %% [markdown]
# ### load libraries

# %%
import requests 
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## load our first page

# %%
# load the website
r = requests.get("https://keithgalli.github.io/web-scraping/example.html")
# convert to beatiful object
soup = bs(r.content)
# print out our html
print(soup.prettify()) # or just print(soup)
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## start using beautiful souap library

# %%
first_header = soup.find("h2")
print(first_header)
print("------------------")
headers = soup.find_all("h2")
print(headers)
# Out:
# <h2>A Header</h2>
# ------------------
# [<h2>A Header</h2>, <h2>Another header</h2>]

# %%
first_header = soup.find(["h1", "h2"])
# first_header = soup.find_all(["h1", "h2"])
print(first_header)
# Out:
# <h1>HTML Webpage</h1>

# %%
# you can pass in ettributes to the find and find_all
paragraph = soup.find_all("p" , attrs={"id":"paragraph-id"})
paragraph
# Out:
# [<p id="paragraph-id"><b>Some bold text</b></p>]

# %%
# you can nest find/find-all
body = soup.find("body")
div = body.find("div")
header = div.find("h1")
header
# Out:
# <h1>HTML Webpage</h1>

# %%
# we can search for specific string in our find / find-all
import re
soup.find_all("p",string="Some bold text") # must insert complete text
soup.find_all("p",string=re.compile("Some")) # can insert some part of text
# Out:
# [<p><i>Some italicized text</i></p>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %% [markdown]
# ## select (css selector)
# use css selectors

# %%
content = soup.select("p")
content
# Out:
# [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>,
#  <p><i>Some italicized text</i></p>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
soup.body.prettify()
print(soup.select("div p")[0].prettify())
# Out:
# <p>
#  Link to more interesting example:
#  <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#   keithgalli.github.io/web-scraping/webpage.html
#  </a>
# </p>

# %%
paragraphs = soup.select("h2 ~ p")
for paragraph in paragraphs : 
    print(paragraph.select("i"))
# Out:
# [<i>Some italicized text</i>]
# []

# %% [markdown]
# ## get different propertties of the HTML

# %%
header = soup.find("h2")
print(header.string)
print("-----")
div = soup.find("div")
print(div.prettify())
print(div.get_text())
# Out:
# A Header
# -----
# <div align="middle">
#  <h1>
#   HTML Webpage
#  </h1>
#  <p>
#   Link to more interesting example:
#   <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#    keithgalli.github.io/web-scraping/webpage.html
#   </a>
#  </p>
# </div>
#
#
# HTML Webpage
# Link to more interesting example: keithgalli.github.io/web-scraping/webpage.html

# %%
link = soup.find("a")
link["href"]
paragraphs = soup.select("p#paragraph-id")
paragraphs[0]["id"]
# Out:
# 'paragraph-id'

# %% [markdown]
# ## code navigation

# %%
soup.body.div.h1.string
# Out:
# 'HTML Webpage'

# %%
# know the terms :parent, sibling and child 
## i know 
soup.body.find("div").find_next_siblings()
# Out:
# [<h2>A Header</h2>,
#  <p><i>Some italicized text</i></p>,
#  <h2>Another header</h2>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]
